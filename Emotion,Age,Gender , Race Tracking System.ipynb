# %%
import cv2
from deepface import DeepFace

# %%
img = cv2.imread('image1.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) # this is in BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 717ms/step
# Action: age:  25%|██▌       | 1/4 [00:03<00:09,  3.02s/it]
# 1/1 [==============================] - 1s 1s/step
# Action: gender:  50%|█████     | 2/4 [00:04<00:04,  2.16s/it]
# 1/1 [==============================] - 1s 1s/step
# Action: race:  75%|███████▌  | 3/4 [00:05<00:01,  1.80s/it]
# 1/1 [==============================] - 1s 1s/step
# Action: race: 100%|██████████| 4/4 [00:07<00:00,  1.80s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.0001123500758021229,
#   'disgust': 1.1020832089539784e-08,
#   'fear': 8.758279868473928e-09,
#   'happy': 98.14490653811771,
#   'sad': 0.0002051160680684673,
#   'surprise': 0.00041734634096648695,
#   'neutral': 1.8543629323676745},
#  'dominant_emotion': 'happy',
#  'region': {'x': 392, 'y': 356, 'w': 175, 'h': 175},
#  'age': 23,
#  'gender': 'Man',
#  'race': {'asian': 10.35207610105561,
#   'indian': 39.255620329902136,
#   'black': 19.369573072245945,
#   'white': 4.68675252059072,
#   'middle eastern': 5.397306856834071,
#   'latino hispanic': 20.93867111937152},
#  'dominant_race': 'indian'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
predictions['dominant_race']
# Out:
# 'indian'

# %%
predictions['gender']
# Out:
# 'Man'

# %%
predictions['age']
# Out:
# 23
